# %% [markdown]
# The networks found with Signor and Omnipath present some dicsonnected components (ax: HOXD9 and HOXD13).
# Moreover, the network found with signor, introduced some complexes (C92, C6, C143...) that are missing the complementary gene/s.
# In the following notebook, using the different strategies available in NeKo, we will try to complete the network using both SIGNOR and Omnipath.

# %%
from neko.core.network import Network
from neko._visual.visualize_network import NetworkVisualizer
from neko._inputs.resources import Resources
from neko._annotations.gene_ontology import Ontology
import omnipath as op
import pandas as pd
from neko._methods.compare import compare_networks
from yfiles_jupyter_graphs import GraphWidget

# %%
resources_signor = Resources()
resources_signor.import_signor_tsv("../data/all_data_02_07_24.tsv")

# %%
invasion_net = Network(sif_file="../sif_files/network_invasion.sif", resources=resources_signor.interactions)

# %%
signor_initial_nodes = ["SRC", "NOTCH1", "PTK2", "CDH1", "CDH2", "VIM", "PIK3CA", "TWIST1", "SNAI1", "SNAI2",
         "ZEB2", "HIF1A", "DKK1", "RAC1", "YAP1", "TP53", "TP63", "TP73", "CTNNB1", "SMAD1", 
         "SMAD2", "TGFBR1"]

# %% [markdown]
# The following are the complex introduced by the NeKo from the Signor database

# %%
for node in invasion_net.nodes["Genesymbol"]:
    if node.startswith("SIGNOR"):
        print(node)
# Out:
# SIGNOR-C156
# SIGNOR-C186
# SIGNOR-C29
# SIGNOR-PF43
# SIGNOR-PF24
# SIGNOR-PF13

# %%
signor_complexes = pd.read_csv("../data/SIGNOR_complexes.csv", sep=';')
signor_pf = pd.read_csv("../data/SIGNOR_PF.csv", sep=";")

# %%
signor_pf
# Out:
#        SIGNOR ID      PROT. FAMILY NAME  \
# 0     SIGNOR-PF1                 ERK1/2
# 1     SIGNOR-PF2                   LPAR
# 2     SIGNOR-PF3                 Ggamma
# 3     SIGNOR-PF4                  Gbeta
# 4     SIGNOR-PF5                   TGFb
# ..           ...                    ...
# 85  SIGNOR-PF105  E2 conjugating enzyme
# 86  SIGNOR-PF106         RING E3 ligase
# 87  SIGNOR-PF107          RBR E3 ligase
# 88  SIGNOR-PF108             CGB Family
# 89  SIGNOR-PF110           TUBAC Family
#
#                                      LIST OF ENTITIES
# 0                                     P27361,  P28482
# 1                            Q92633,  Q9HBW0,  Q9UBY5
# 2   O14610,  O60262,  P50150,  P50151,  P59768,  P...
# 3          O14775,  P16520,  P62873,  P62879,  Q9HAV0
# 4                            P01137,  P10600,  P61812
# ..                                                ...
# 85  A0A1B0GUS4,  O00762,  O14933,  P49459,  P51668...
# 86  A0AVI4,  A1L020,  A6NCK2,  A6NCQ9,  A6NDI0,  A...
# 87  O60260,  O95376,  P50876,  Q7Z419,  Q8IWT3,  Q...
# 88                                    P0DN86,  P0DN87
# 89                                    P0DPH7,  P0DPH8
#
# [90 rows x 3 columns]

# %%
signor_complexes
# Out:
#        SIGNOR ID                     COMPLEX NAME  \
# 0      SIGNOR-C1                              NFY
# 1      SIGNOR-C2                           mTORC2
# 2      SIGNOR-C3                           mTORC1
# 3      SIGNOR-C5                     SCF-betaTRCP
# 4      SIGNOR-C6                         CBP/p300
# ..           ...                              ...
# 511  SIGNOR-C550         CORVET tethering complex
# 512  SIGNOR-C551        STX17-VAMP8 SNARE complex
# 513  SIGNOR-C552                     STK35/PDIK1L
# 514  SIGNOR-C553  PAN2-PAN3 deadenylation complex
# 515  SIGNOR-C554                              CPC
#
#                                       LIST OF ENTITIES
# 0                             P23511,  P25208,  Q13952
# 1    P42345,  P68104,  P85299,  Q6R327,  Q8TB45,  Q...
# 2           P42345,  Q8N122,  Q8TB45,  Q96B36,  Q9BVC4
# 3                             P63208,  Q13616,  Q9Y297
# 4                                      Q09472,  Q92793
# ..                                                 ...
# 511  Q8N3P4,  Q8WUH2,  Q96AX1,  Q9H269,  Q9H270,  Q...
# 512                           O95721,  P56962,  Q9BV40
# 513                                    Q8N165,  Q8TDR2
# 514                                    Q504Q3,  Q58A45
# 515                  O15392,  Q53HL2,  Q96GD4,  Q9NQS7
#
# [516 rows x 3 columns]

# %%
for ID in signor_complexes["SIGNOR ID"]:
    if ID in invasion_net.nodes["Genesymbol"].to_list():
        print(ID, ': ', signor_complexes.loc[signor_complexes["SIGNOR ID"] == ID]["LIST OF ENTITIES"].item(), signor_complexes.loc[signor_complexes["SIGNOR ID"] == ID]["COMPLEX NAME"].item())
# Out:
# SIGNOR-C29 :  O00238,  P36894,  Q13873 BMPR1A/1B/2
# SIGNOR-C156 :  P27986,  P42336 PI3K
# SIGNOR-C186 :  P26010,  P38570 AE/b7 integrin

# %%
for ID in signor_pf["SIGNOR ID"]:
    if ID in invasion_net.nodes["Genesymbol"].to_list():
        print(ID, ': ', signor_pf.loc[signor_pf["SIGNOR ID"] == ID]["PROT. FAMILY NAME"].item() + "_family")
# Out:
# SIGNOR-PF13 :  PAK_family
# SIGNOR-PF24 :  AKT_family
# SIGNOR-PF43 :  LATS1/2_family

# %%
# Here I am adding all the nodes that are part of each complex in the network
for ID in signor_complexes["SIGNOR ID"]:
    if ID in invasion_net.nodes["Genesymbol"].to_list():
        nodes = [item.strip() for item in signor_complexes.loc[signor_complexes["SIGNOR ID"] == ID]["LIST OF ENTITIES"].item().split(',')]
        for node in nodes: invasion_net.add_node(node)

# %%
# now I will use the function "connect_nodes" to search for direct connection between nodes (so paths with length 1)

invasion_net.connect_nodes(only_signed=True, consensus_only=False)

# %%
invasion_net_visualizer = NetworkVisualizer(invasion_net)
invasion_net_visualizer.render(output_file="net_invasion", view=True)

# %% [markdown]
# Signor uses its own way to name complexes and protein families. In order to make the network easier to read, we ae going to change name to those nodes automatically using a specific function in NeKo:

# %%
# Here I change the name of the complexes for better readability
for ID in signor_complexes["SIGNOR ID"]:
    if ID in invasion_net.nodes["Genesymbol"].to_list():
        new_name = signor_complexes.loc[signor_complexes["SIGNOR ID"] == ID]["COMPLEX NAME"].item()
        invasion_net.modify_node_name(old_name=ID, new_name=new_name, type="both")

# %%
# Here I change the name of the protein families for better readability
for ID in signor_pf["SIGNOR ID"]:
    if ID in invasion_net.nodes["Genesymbol"].to_list():
        new_name = signor_pf.loc[signor_pf["SIGNOR ID"] == ID]["PROT. FAMILY NAME"].item() + "_family"
        invasion_net.modify_node_name(old_name=ID, new_name=new_name, type="both")

# %%
# and here I remove the nodes that form complexes but that have no sources (basically useless input)
complexes_nodes = []
for ID in signor_complexes["COMPLEX NAME"]:
    if ID in invasion_net.nodes["Genesymbol"].to_list():
        nodes = [item.strip() for item in signor_complexes.loc[signor_complexes["COMPLEX NAME"] == ID]["LIST OF ENTITIES"].item().split(',')]
        complexes_nodes.extend(nodes)
print(complexes_nodes)       
for node in invasion_net.nodes["Uniprot"].unique():
    if node in complexes_nodes:
        if node not in invasion_net.edges["target"].unique():
            invasion_net.remove_node(node)
# Out:
# ['O00238', 'P36894', 'Q13873', 'P27986', 'P42336', 'P26010', 'P38570']

# %%
invasion_net_visualizer = NetworkVisualizer(invasion_net)
invasion_net_visualizer.render(output_file="net_signor_invasion", view=True)

# %%
from neko._outputs.exports import Exports

# %%
export = Exports(invasion_net)

# %%
export.export_sif( "../sif_files/Signor_with_complexes.sif")

# %%
export.export_bnet("./bnets/Invasion_net")
# Out:
# Warning: The network has 13 BIMODAL interaction(s).
# Bimodal interactions:
# MYC -> cell-cell_adhesion
# Reference: SIF file
# AKT1 -> cell_migration
# Reference: SIF file
# MAPK8 -> apoptotic_process
# Reference: SIF file
# MAPK8 -> cell-cell_adhesion
# Reference: SIF file
# PTEN -> cell_migration
# Reference: SIF file
# CSNK2A1 -> TP53
# Reference: SIF file; 10747897; 12628923
# CSNK2A1 -> cell-cell_adhesion
# Reference: SIF file
# MDM2 -> apoptotic_process
# Reference: SIF file
# PAK2 -> apoptotic_process
# Reference: SIF file
# ROCK1 -> cell_migration
# Reference: SIF file
# PRKD1 -> cell_migration
# Reference: SIF file
# MAPK14 -> AKT_family
# Reference: SIF file; 12181443; 20626350
# SIAH1 -> apoptotic_process
# Reference: SIF file
# Created BNet file: ./bnets/Invasion_net_1.bnet
# Created BNet file: ./bnets/Invasion_net_2.bnet
# Created BNet file: ./bnets/Invasion_net_3.bnet
# Created BNet file: ./bnets/Invasion_net_4.bnet
# Created BNet file: ./bnets/Invasion_net_5.bnet
# Created BNet file: ./bnets/Invasion_net_6.bnet
# Created BNet file: ./bnets/Invasion_net_7.bnet
# Created BNet file: ./bnets/Invasion_net_8.bnet
# Created BNet file: ./bnets/Invasion_net_9.bnet
# Created BNet file: ./bnets/Invasion_net_10.bnet
# Created BNet file: ./bnets/Invasion_net_11.bnet
# Created BNet file: ./bnets/Invasion_net_12.bnet
# Created BNet file: ./bnets/Invasion_net_13.bnet
# Created BNet file: ./bnets/Invasion_net_14.bnet
# Created BNet file: ./bnets/Invasion_net_15.bnet
# Created BNet file: ./bnets/Invasion_net_16.bnet
# Created BNet file: ./bnets/Invasion_net_17.bnet
# Created BNet file: ./bnets/Invasion_net_18.bnet
# Created BNet file: ./bnets/Invasion_net_19.bnet
# Created BNet file: ./bnets/Invasion_net_20.bnet
# Created BNet file: ./bnets/Invasion_net_21.bnet
# Created BNet file: ./bnets/Invasion_net_22.bnet
# Created BNet file: ./bnets/Invasion_net_23.bnet
# Created BNet file: ./bnets/Invasion_net_24.bnet
# Created BNet file: ./bnets/Invasion_net_25.bnet
# Created BNet file: ./bnets/Invasion_net_26.bnet
# Created BNet file: ./bnets/Invasion_net_27.bnet
# Created BNet file: ./bnets/Invasion_net_28.bnet
# Created BNet file: ./bnets/Invasion_net_29.bnet
# Created BNet file: ./bnets/Invasion_net_30.bnet
# Created BNet file: ./bnets/Invasion_net_31.bnet
# Created BNet file: ./bnets/Invasion_net_32.bnet
# Created BNet file: ./bnets/Invasion_net_33.bnet
# Created BNet file: ./bnets/Invasion_net_34.bnet
# Created BNet file: ./bnets/Invasion_net_35.bnet
# Created BNet file: ./bnets/Invasion_net_36.bnet
# Created BNet file: ./bnets/Invasion_net_37.bnet
# Created BNet file: ./bnets/Invasion_net_38.bnet
# Created BNet file: ./bnets/Invasion_net_39.bnet
# Created BNet file: ./bnets/Invasion_net_40.bnet
# Created BNet file: ./bnets/Invasion_net_41.bnet
# Created BNet file: ./bnets/Invasion_net_42.bnet
# Created BNet file: ./bnets/Invasion_net_43.bnet
# Created BNet file: ./bnets/Invasion_net_44.bnet
# Created BNet file: ./bnets/Invasion_net_45.bnet
# Created BNet file: ./bnets/Invasion_net_46.bnet
# Created BNet file: ./bnets/Invasion_net_47.bnet
# Created BNet file: ./bnets/Invasion_net_48.bnet
# Created BNet file: ./bnets/Invasion_net_49.bnet
# Created BNet file: ./bnets/Invasion_net_50.bnet
# Created BNet file: ./bnets/Invasion_net_51.bnet
# Created BNet file: ./bnets/Invasion_net_52.bnet
# Created BNet file: ./bnets/Invasion_net_53.bnet
# Created BNet file: ./bnets/Invasion_net_54.bnet
# Created BNet file: ./bnets/Invasion_net_55.bnet
# Created BNet file: ./bnets/Invasion_net_56.bnet
# Created BNet file: ./bnets/Invasion_net_57.bnet
# Created BNet file: ./bnets/Invasion_net_58.bnet
# Created BNet file: ./bnets/Invasion_net_59.bnet
# Created BNet file: ./bnets/Invasion_net_60.bnet
# Created BNet file: ./bnets/Invasion_net_61.bnet
# Created BNet file: ./bnets/Invasion_net_62.bnet
# Created BNet file: ./bnets/Invasion_net_63.bnet
# Created BNet file: ./bnets/Invasion_net_64.bnet
# Created BNet file: ./bnets/Invasion_net_65.bnet
# Created BNet file: ./bnets/Invasion_net_66.bnet
# Created BNet file: ./bnets/Invasion_net_67.bnet
# Created BNet file: ./bnets/Invasion_net_68.bnet
# Created BNet file: ./bnets/Invasion_net_69.bnet
# Created BNet file: ./bnets/Invasion_net_70.bnet
# Created BNet file: ./bnets/Invasion_net_71.bnet
# Created BNet file: ./bnets/Invasion_net_72.bnet
# Created BNet file: ./bnets/Invasion_net_73.bnet
# Created BNet file: ./bnets/Invasion_net_74.bnet
# Created BNet file: ./bnets/Invasion_net_75.bnet
# Created BNet file: ./bnets/Invasion_net_76.bnet
# Created BNet file: ./bnets/Invasion_net_77.bnet
# Created BNet file: ./bnets/Invasion_net_78.bnet
# Created BNet file: ./bnets/Invasion_net_79.bnet
# Created BNet file: ./bnets/Invasion_net_80.bnet
# Created BNet file: ./bnets/Invasion_net_81.bnet
# Created BNet file: ./bnets/Invasion_net_82.bnet
# Created BNet file: ./bnets/Invasion_net_83.bnet
# Created BNet file: ./bnets/Invasion_net_84.bnet
# Created BNet file: ./bnets/Invasion_net_85.bnet
# Created BNet file: ./bnets/Invasion_net_86.bnet
# Created BNet file: ./bnets/Invasion_net_87.bnet
# Created BNet file: ./bnets/Invasion_net_88.bnet
# Created BNet file: ./bnets/Invasion_net_89.bnet
# Created BNet file: ./bnets/Invasion_net_90.bnet
# Created BNet file: ./bnets/Invasion_net_91.bnet
# Created BNet file: ./bnets/Invasion_net_92.bnet
# Created BNet file: ./bnets/Invasion_net_93.bnet
# Created BNet file: ./bnets/Invasion_net_94.bnet
# Created BNet file: ./bnets/Invasion_net_95.bnet
# Created BNet file: ./bnets/Invasion_net_96.bnet
# Created BNet file: ./bnets/Invasion_net_97.bnet
# Created BNet file: ./bnets/Invasion_net_98.bnet
# Created BNet file: ./bnets/Invasion_net_99.bnet
# Created BNet file: ./bnets/Invasion_net_100.bnet
# Created BNet file: ./bnets/Invasion_net_101.bnet
# Created BNet file: ./bnets/Invasion_net_102.bnet
# Created BNet file: ./bnets/Invasion_net_103.bnet
# Created BNet file: ./bnets/Invasion_net_104.bnet
# Created BNet file: ./bnets/Invasion_net_105.bnet
# Created BNet file: ./bnets/Invasion_net_106.bnet
# Created BNet file: ./bnets/Invasion_net_107.bnet
# Created BNet file: ./bnets/Invasion_net_108.bnet
# Created BNet file: ./bnets/Invasion_net_109.bnet
# Created BNet file: ./bnets/Invasion_net_110.bnet
# Created BNet file: ./bnets/Invasion_net_111.bnet
# Created BNet file: ./bnets/Invasion_net_112.bnet
# Created BNet file: ./bnets/Invasion_net_113.bnet
# Created BNet file: ./bnets/Invasion_net_114.bnet
# Created BNet file: ./bnets/Invasion_net_115.bnet
# Created BNet file: ./bnets/Invasion_net_116.bnet
# Created BNet file: ./bnets/Invasion_net_117.bnet
# Created BNet file: ./bnets/Invasion_net_118.bnet
# Created BNet file: ./bnets/Invasion_net_119.bnet
# Created BNet file: ./bnets/Invasion_net_120.bnet
# Created BNet file: ./bnets/Invasion_net_121.bnet
# Created BNet file: ./bnets/Invasion_net_122.bnet
# Created BNet file: ./bnets/Invasion_net_123.bnet
# Created BNet file: ./bnets/Invasion_net_124.bnet
# Created BNet file: ./bnets/Invasion_net_125.bnet
# Created BNet file: ./bnets/Invasion_net_126.bnet
# Created BNet file: ./bnets/Invasion_net_127.bnet
# Created BNet file: ./bnets/Invasion_net_128.bnet
# Created BNet file: ./bnets/Invasion_net_129.bnet
# Created BNet file: ./bnets/Invasion_net_130.bnet
# Created BNet file: ./bnets/Invasion_net_131.bnet
# Created BNet file: ./bnets/Invasion_net_132.bnet
# Created BNet file: ./bnets/Invasion_net_133.bnet
# Created BNet file: ./bnets/Invasion_net_134.bnet
# Created BNet file: ./bnets/Invasion_net_135.bnet
# Created BNet file: ./bnets/Invasion_net_136.bnet
# Created BNet file: ./bnets/Invasion_net_137.bnet
# Created BNet file: ./bnets/Invasion_net_138.bnet
# Created BNet file: ./bnets/Invasion_net_139.bnet
# Created BNet file: ./bnets/Invasion_net_140.bnet
# Created BNet file: ./bnets/Invasion_net_141.bnet
# Created BNet file: ./bnets/Invasion_net_142.bnet
# Created BNet file: ./bnets/Invasion_net_143.bnet
# Created BNet file: ./bnets/Invasion_net_144.bnet
# Created BNet file: ./bnets/Invasion_net_145.bnet
# Created BNet file: ./bnets/Invasion_net_146.bnet
# Created BNet file: ./bnets/Invasion_net_147.bnet
# Created BNet file: ./bnets/Invasion_net_148.bnet
# Created BNet file: ./bnets/Invasion_net_149.bnet
# Created BNet file: ./bnets/Invasion_net_150.bnet
# Created BNet file: ./bnets/Invasion_net_151.bnet
# Created BNet file: ./bnets/Invasion_net_152.bnet
# Created BNet file: ./bnets/Invasion_net_153.bnet
# Created BNet file: ./bnets/Invasion_net_154.bnet
# Created BNet file: ./bnets/Invasion_net_155.bnet
# Created BNet file: ./bnets/Invasion_net_156.bnet
# Created BNet file: ./bnets/Invasion_net_157.bnet
# Created BNet file: ./bnets/Invasion_net_158.bnet
# Created BNet file: ./bnets/Invasion_net_159.bnet
# Created BNet file: ./bnets/Invasion_net_160.bnet
# Created BNet file: ./bnets/Invasion_net_161.bnet
# Created BNet file: ./bnets/Invasion_net_162.bnet
# Created BNet file: ./bnets/Invasion_net_163.bnet
# Created BNet file: ./bnets/Invasion_net_164.bnet
# Created BNet file: ./bnets/Invasion_net_165.bnet
# Created BNet file: ./bnets/Invasion_net_166.bnet
# Created BNet file: ./bnets/Invasion_net_167.bnet
# Created BNet file: ./bnets/Invasion_net_168.bnet
# Created BNet file: ./bnets/Invasion_net_169.bnet
# Created BNet file: ./bnets/Invasion_net_170.bnet
# Created BNet file: ./bnets/Invasion_net_171.bnet
# Created BNet file: ./bnets/Invasion_net_172.bnet
# Created BNet file: ./bnets/Invasion_net_173.bnet
# Created BNet file: ./bnets/Invasion_net_174.bnet
# Created BNet file: ./bnets/Invasion_net_175.bnet
# Created BNet file: ./bnets/Invasion_net_176.bnet
# Created BNet file: ./bnets/Invasion_net_177.bnet
# Created BNet file: ./bnets/Invasion_net_178.bnet
# Created BNet file: ./bnets/Invasion_net_179.bnet
# Created BNet file: ./bnets/Invasion_net_180.bnet
# Created BNet file: ./bnets/Invasion_net_181.bnet
# Created BNet file: ./bnets/Invasion_net_182.bnet
# Created BNet file: ./bnets/Invasion_net_183.bnet
# Created BNet file: ./bnets/Invasion_net_184.bnet
# Created BNet file: ./bnets/Invasion_net_185.bnet
# Created BNet file: ./bnets/Invasion_net_186.bnet
# Created BNet file: ./bnets/Invasion_net_187.bnet
# Created BNet file: ./bnets/Invasion_net_188.bnet
# Created BNet file: ./bnets/Invasion_net_189.bnet
# Created BNet file: ./bnets/Invasion_net_190.bnet
# Created BNet file: ./bnets/Invasion_net_191.bnet
# Created BNet file: ./bnets/Invasion_net_192.bnet
# Created BNet file: ./bnets/Invasion_net_193.bnet
# Created BNet file: ./bnets/Invasion_net_194.bnet
# Created BNet file: ./bnets/Invasion_net_195.bnet
# Created BNet file: ./bnets/Invasion_net_196.bnet
# Created BNet file: ./bnets/Invasion_net_197.bnet
# Created BNet file: ./bnets/Invasion_net_198.bnet
# Created BNet file: ./bnets/Invasion_net_199.bnet
# Created BNet file: ./bnets/Invasion_net_200.bnet
# Created BNet file: ./bnets/Invasion_net_201.bnet
# Created BNet file: ./bnets/Invasion_net_202.bnet
# Created BNet file: ./bnets/Invasion_net_203.bnet
# Created BNet file: ./bnets/Invasion_net_204.bnet
# Created BNet file: ./bnets/Invasion_net_205.bnet
# Created BNet file: ./bnets/Invasion_net_206.bnet
# Created BNet file: ./bnets/Invasion_net_207.bnet
# Created BNet file: ./bnets/Invasion_net_208.bnet
# Created BNet file: ./bnets/Invasion_net_209.bnet
# Created BNet file: ./bnets/Invasion_net_210.bnet
# Created BNet file: ./bnets/Invasion_net_211.bnet
# Created BNet file: ./bnets/Invasion_net_212.bnet
# Created BNet file: ./bnets/Invasion_net_213.bnet
# Created BNet file: ./bnets/Invasion_net_214.bnet
# Created BNet file: ./bnets/Invasion_net_215.bnet
# Created BNet file: ./bnets/Invasion_net_216.bnet
# Created BNet file: ./bnets/Invasion_net_217.bnet
# Created BNet file: ./bnets/Invasion_net_218.bnet
# Created BNet file: ./bnets/Invasion_net_219.bnet
# Created BNet file: ./bnets/Invasion_net_220.bnet
# Created BNet file: ./bnets/Invasion_net_221.bnet
# Created BNet file: ./bnets/Invasion_net_222.bnet
# Created BNet file: ./bnets/Invasion_net_223.bnet
# Created BNet file: ./bnets/Invasion_net_224.bnet
# Created BNet file: ./bnets/Invasion_net_225.bnet
# Created BNet file: ./bnets/Invasion_net_226.bnet
# Created BNet file: ./bnets/Invasion_net_227.bnet
# Created BNet file: ./bnets/Invasion_net_228.bnet
# Created BNet file: ./bnets/Invasion_net_229.bnet
# Created BNet file: ./bnets/Invasion_net_230.bnet
# Created BNet file: ./bnets/Invasion_net_231.bnet
# Created BNet file: ./bnets/Invasion_net_232.bnet
# Created BNet file: ./bnets/Invasion_net_233.bnet
# Created BNet file: ./bnets/Invasion_net_234.bnet
# Created BNet file: ./bnets/Invasion_net_235.bnet
# Created BNet file: ./bnets/Invasion_net_236.bnet
# Created BNet file: ./bnets/Invasion_net_237.bnet
# Created BNet file: ./bnets/Invasion_net_238.bnet
# Created BNet file: ./bnets/Invasion_net_239.bnet
# Created BNet file: ./bnets/Invasion_net_240.bnet
# Created BNet file: ./bnets/Invasion_net_241.bnet
# Created BNet file: ./bnets/Invasion_net_242.bnet
# Created BNet file: ./bnets/Invasion_net_243.bnet
# Created BNet file: ./bnets/Invasion_net_244.bnet
# Created BNet file: ./bnets/Invasion_net_245.bnet
# Created BNet file: ./bnets/Invasion_net_246.bnet
# Created BNet file: ./bnets/Invasion_net_247.bnet
# Created BNet file: ./bnets/Invasion_net_248.bnet
# Created BNet file: ./bnets/Invasion_net_249.bnet
# Created BNet file: ./bnets/Invasion_net_250.bnet
# Created BNet file: ./bnets/Invasion_net_251.bnet
# Created BNet file: ./bnets/Invasion_net_252.bnet
# Created BNet file: ./bnets/Invasion_net_253.bnet
# Created BNet file: ./bnets/Invasion_net_254.bnet
# Created BNet file: ./bnets/Invasion_net_255.bnet
# Created BNet file: ./bnets/Invasion_net_256.bnet
# Created BNet file: ./bnets/Invasion_net_257.bnet
# Created BNet file: ./bnets/Invasion_net_258.bnet
# Created BNet file: ./bnets/Invasion_net_259.bnet
# Created BNet file: ./bnets/Invasion_net_260.bnet
# Created BNet file: ./bnets/Invasion_net_261.bnet
# Created BNet file: ./bnets/Invasion_net_262.bnet
# Created BNet file: ./bnets/Invasion_net_263.bnet
# Created BNet file: ./bnets/Invasion_net_264.bnet
# Created BNet file: ./bnets/Invasion_net_265.bnet
# Created BNet file: ./bnets/Invasion_net_266.bnet
# Created BNet file: ./bnets/Invasion_net_267.bnet
# Created BNet file: ./bnets/Invasion_net_268.bnet
# Created BNet file: ./bnets/Invasion_net_269.bnet
# Created BNet file: ./bnets/Invasion_net_270.bnet
# Created BNet file: ./bnets/Invasion_net_271.bnet
# Created BNet file: ./bnets/Invasion_net_272.bnet
# Created BNet file: ./bnets/Invasion_net_273.bnet
# Created BNet file: ./bnets/Invasion_net_274.bnet
# Created BNet file: ./bnets/Invasion_net_275.bnet
# Created BNet file: ./bnets/Invasion_net_276.bnet
# Created BNet file: ./bnets/Invasion_net_277.bnet
# Created BNet file: ./bnets/Invasion_net_278.bnet
# Created BNet file: ./bnets/Invasion_net_279.bnet
# Created BNet file: ./bnets/Invasion_net_280.bnet
# Created BNet file: ./bnets/Invasion_net_281.bnet
# Created BNet file: ./bnets/Invasion_net_282.bnet
# Created BNet file: ./bnets/Invasion_net_283.bnet
# Created BNet file: ./bnets/Invasion_net_284.bnet
# Created BNet file: ./bnets/Invasion_net_285.bnet
# Created BNet file: ./bnets/Invasion_net_286.bnet
# Created BNet file: ./bnets/Invasion_net_287.bnet
# Created BNet file: ./bnets/Invasion_net_288.bnet
# Created BNet file: ./bnets/Invasion_net_289.bnet
# Created BNet file: ./bnets/Invasion_net_290.bnet
# Created BNet file: ./bnets/Invasion_net_291.bnet
# Created BNet file: ./bnets/Invasion_net_292.bnet
# Created BNet file: ./bnets/Invasion_net_293.bnet
# Created BNet file: ./bnets/Invasion_net_294.bnet
# Created BNet file: ./bnets/Invasion_net_295.bnet
# Created BNet file: ./bnets/Invasion_net_296.bnet
# Created BNet file: ./bnets/Invasion_net_297.bnet
# Created BNet file: ./bnets/Invasion_net_298.bnet
# Created BNet file: ./bnets/Invasion_net_299.bnet
# Created BNet file: ./bnets/Invasion_net_300.bnet
# Created BNet file: ./bnets/Invasion_net_301.bnet
# Created BNet file: ./bnets/Invasion_net_302.bnet
# Created BNet file: ./bnets/Invasion_net_303.bnet
# Created BNet file: ./bnets/Invasion_net_304.bnet
# Created BNet file: ./bnets/Invasion_net_305.bnet
# Created BNet file: ./bnets/Invasion_net_306.bnet
# Created BNet file: ./bnets/Invasion_net_307.bnet
# Created BNet file: ./bnets/Invasion_net_308.bnet
# Created BNet file: ./bnets/Invasion_net_309.bnet
# Created BNet file: ./bnets/Invasion_net_310.bnet
# Created BNet file: ./bnets/Invasion_net_311.bnet
# Created BNet file: ./bnets/Invasion_net_312.bnet
# Created BNet file: ./bnets/Invasion_net_313.bnet
# Created BNet file: ./bnets/Invasion_net_314.bnet
# Created BNet file: ./bnets/Invasion_net_315.bnet
# Created BNet file: ./bnets/Invasion_net_316.bnet
# Created BNet file: ./bnets/Invasion_net_317.bnet
# Created BNet file: ./bnets/Invasion_net_318.bnet
# Created BNet file: ./bnets/Invasion_net_319.bnet
# Created BNet file: ./bnets/Invasion_net_320.bnet
# Created BNet file: ./bnets/Invasion_net_321.bnet
# Created BNet file: ./bnets/Invasion_net_322.bnet
# Created BNet file: ./bnets/Invasion_net_323.bnet
# Created BNet file: ./bnets/Invasion_net_324.bnet
# Created BNet file: ./bnets/Invasion_net_325.bnet
# Created BNet file: ./bnets/Invasion_net_326.bnet
# Created BNet file: ./bnets/Invasion_net_327.bnet
# Created BNet file: ./bnets/Invasion_net_328.bnet
# Created BNet file: ./bnets/Invasion_net_329.bnet
# Created BNet file: ./bnets/Invasion_net_330.bnet
# Created BNet file: ./bnets/Invasion_net_331.bnet
# Created BNet file: ./bnets/Invasion_net_332.bnet
# Created BNet file: ./bnets/Invasion_net_333.bnet
# Created BNet file: ./bnets/Invasion_net_334.bnet
# Created BNet file: ./bnets/Invasion_net_335.bnet
# Created BNet file: ./bnets/Invasion_net_336.bnet
# Created BNet file: ./bnets/Invasion_net_337.bnet
# Created BNet file: ./bnets/Invasion_net_338.bnet
# Created BNet file: ./bnets/Invasion_net_339.bnet
# Created BNet file: ./bnets/Invasion_net_340.bnet
# Created BNet file: ./bnets/Invasion_net_341.bnet
# Created BNet file: ./bnets/Invasion_net_342.bnet
# Created BNet file: ./bnets/Invasion_net_343.bnet
# Created BNet file: ./bnets/Invasion_net_344.bnet
# Created BNet file: ./bnets/Invasion_net_345.bnet
# Created BNet file: ./bnets/Invasion_net_346.bnet
# Created BNet file: ./bnets/Invasion_net_347.bnet
# Created BNet file: ./bnets/Invasion_net_348.bnet
# Created BNet file: ./bnets/Invasion_net_349.bnet
# Created BNet file: ./bnets/Invasion_net_350.bnet
# Created BNet file: ./bnets/Invasion_net_351.bnet
# Created BNet file: ./bnets/Invasion_net_352.bnet
# Created BNet file: ./bnets/Invasion_net_353.bnet
# Created BNet file: ./bnets/Invasion_net_354.bnet
# Created BNet file: ./bnets/Invasion_net_355.bnet
# Created BNet file: ./bnets/Invasion_net_356.bnet
# Created BNet file: ./bnets/Invasion_net_357.bnet
# Created BNet file: ./bnets/Invasion_net_358.bnet
# Created BNet file: ./bnets/Invasion_net_359.bnet
# Created BNet file: ./bnets/Invasion_net_360.bnet
# Created BNet file: ./bnets/Invasion_net_361.bnet
# Created BNet file: ./bnets/Invasion_net_362.bnet
# Created BNet file: ./bnets/Invasion_net_363.bnet
# Created BNet file: ./bnets/Invasion_net_364.bnet
# Created BNet file: ./bnets/Invasion_net_365.bnet
# Created BNet file: ./bnets/Invasion_net_366.bnet
# Created BNet file: ./bnets/Invasion_net_367.bnet
# Created BNet file: ./bnets/Invasion_net_368.bnet
# Created BNet file: ./bnets/Invasion_net_369.bnet
# Created BNet file: ./bnets/Invasion_net_370.bnet
# Created BNet file: ./bnets/Invasion_net_371.bnet
# Created BNet file: ./bnets/Invasion_net_372.bnet
# Created BNet file: ./bnets/Invasion_net_373.bnet
# Created BNet file: ./bnets/Invasion_net_374.bnet
# Created BNet file: ./bnets/Invasion_net_375.bnet
# Created BNet file: ./bnets/Invasion_net_376.bnet
# Created BNet file: ./bnets/Invasion_net_377.bnet
# Created BNet file: ./bnets/Invasion_net_378.bnet
# Created BNet file: ./bnets/Invasion_net_379.bnet
# Created BNet file: ./bnets/Invasion_net_380.bnet
# Created BNet file: ./bnets/Invasion_net_381.bnet
# Created BNet file: ./bnets/Invasion_net_382.bnet
# Created BNet file: ./bnets/Invasion_net_383.bnet
# Created BNet file: ./bnets/Invasion_net_384.bnet
# Created BNet file: ./bnets/Invasion_net_385.bnet
# Created BNet file: ./bnets/Invasion_net_386.bnet
# Created BNet file: ./bnets/Invasion_net_387.bnet
# Created BNet file: ./bnets/Invasion_net_388.bnet
# Created BNet file: ./bnets/Invasion_net_389.bnet
# Created BNet file: ./bnets/Invasion_net_390.bnet
# Created BNet file: ./bnets/Invasion_net_391.bnet
# Created BNet file: ./bnets/Invasion_net_392.bnet
# Created BNet file: ./bnets/Invasion_net_393.bnet
# Created BNet file: ./bnets/Invasion_net_394.bnet
# Created BNet file: ./bnets/Invasion_net_395.bnet
# Created BNet file: ./bnets/Invasion_net_396.bnet
# Created BNet file: ./bnets/Invasion_net_397.bnet
# Created BNet file: ./bnets/Invasion_net_398.bnet
# Created BNet file: ./bnets/Invasion_net_399.bnet
# Created BNet file: ./bnets/Invasion_net_400.bnet
# Created BNet file: ./bnets/Invasion_net_401.bnet
# Created BNet file: ./bnets/Invasion_net_402.bnet
# Created BNet file: ./bnets/Invasion_net_403.bnet
# Created BNet file: ./bnets/Invasion_net_404.bnet
# Created BNet file: ./bnets/Invasion_net_405.bnet
# Created BNet file: ./bnets/Invasion_net_406.bnet
# Created BNet file: ./bnets/Invasion_net_407.bnet
# Created BNet file: ./bnets/Invasion_net_408.bnet
# Created BNet file: ./bnets/Invasion_net_409.bnet
# Created BNet file: ./bnets/Invasion_net_410.bnet
# Created BNet file: ./bnets/Invasion_net_411.bnet
# Created BNet file: ./bnets/Invasion_net_412.bnet
# Created BNet file: ./bnets/Invasion_net_413.bnet
# Created BNet file: ./bnets/Invasion_net_414.bnet
# Created BNet file: ./bnets/Invasion_net_415.bnet
# Created BNet file: ./bnets/Invasion_net_416.bnet
# Created BNet file: ./bnets/Invasion_net_417.bnet
# Created BNet file: ./bnets/Invasion_net_418.bnet
# Created BNet file: ./bnets/Invasion_net_419.bnet
# Created BNet file: ./bnets/Invasion_net_420.bnet
# Created BNet file: ./bnets/Invasion_net_421.bnet
# Created BNet file: ./bnets/Invasion_net_422.bnet
# Created BNet file: ./bnets/Invasion_net_423.bnet
# Created BNet file: ./bnets/Invasion_net_424.bnet
# Created BNet file: ./bnets/Invasion_net_425.bnet
# Created BNet file: ./bnets/Invasion_net_426.bnet
# Created BNet file: ./bnets/Invasion_net_427.bnet
# Created BNet file: ./bnets/Invasion_net_428.bnet
# Created BNet file: ./bnets/Invasion_net_429.bnet
# Created BNet file: ./bnets/Invasion_net_430.bnet
# Created BNet file: ./bnets/Invasion_net_431.bnet
# Created BNet file: ./bnets/Invasion_net_432.bnet
# Created BNet file: ./bnets/Invasion_net_433.bnet
# Created BNet file: ./bnets/Invasion_net_434.bnet
# Created BNet file: ./bnets/Invasion_net_435.bnet
# Created BNet file: ./bnets/Invasion_net_436.bnet
# Created BNet file: ./bnets/Invasion_net_437.bnet
# Created BNet file: ./bnets/Invasion_net_438.bnet
# Created BNet file: ./bnets/Invasion_net_439.bnet
# Created BNet file: ./bnets/Invasion_net_440.bnet
# Created BNet file: ./bnets/Invasion_net_441.bnet
# Created BNet file: ./bnets/Invasion_net_442.bnet
# Created BNet file: ./bnets/Invasion_net_443.bnet
# Created BNet file: ./bnets/Invasion_net_444.bnet
# Created BNet file: ./bnets/Invasion_net_445.bnet
# Created BNet file: ./bnets/Invasion_net_446.bnet
# Created BNet file: ./bnets/Invasion_net_447.bnet
# Created BNet file: ./bnets/Invasion_net_448.bnet
# Created BNet file: ./bnets/Invasion_net_449.bnet
# Created BNet file: ./bnets/Invasion_net_450.bnet
# Created BNet file: ./bnets/Invasion_net_451.bnet
# Created BNet file: ./bnets/Invasion_net_452.bnet
# Created BNet file: ./bnets/Invasion_net_453.bnet
# Created BNet file: ./bnets/Invasion_net_454.bnet
# Created BNet file: ./bnets/Invasion_net_455.bnet
# Created BNet file: ./bnets/Invasion_net_456.bnet
# Created BNet file: ./bnets/Invasion_net_457.bnet
# Created BNet file: ./bnets/Invasion_net_458.bnet
# Created BNet file: ./bnets/Invasion_net_459.bnet
# Created BNet file: ./bnets/Invasion_net_460.bnet
# Created BNet file: ./bnets/Invasion_net_461.bnet
# Created BNet file: ./bnets/Invasion_net_462.bnet
# Created BNet file: ./bnets/Invasion_net_463.bnet
# Created BNet file: ./bnets/Invasion_net_464.bnet
# Created BNet file: ./bnets/Invasion_net_465.bnet
# Created BNet file: ./bnets/Invasion_net_466.bnet
# Created BNet file: ./bnets/Invasion_net_467.bnet
# Created BNet file: ./bnets/Invasion_net_468.bnet
# Created BNet file: ./bnets/Invasion_net_469.bnet
# Created BNet file: ./bnets/Invasion_net_470.bnet
# Created BNet file: ./bnets/Invasion_net_471.bnet
# Created BNet file: ./bnets/Invasion_net_472.bnet
# Created BNet file: ./bnets/Invasion_net_473.bnet
# Created BNet file: ./bnets/Invasion_net_474.bnet
# Created BNet file: ./bnets/Invasion_net_475.bnet
# Created BNet file: ./bnets/Invasion_net_476.bnet
# Created BNet file: ./bnets/Invasion_net_477.bnet
# Created BNet file: ./bnets/Invasion_net_478.bnet
# Created BNet file: ./bnets/Invasion_net_479.bnet
# Created BNet file: ./bnets/Invasion_net_480.bnet
# Created BNet file: ./bnets/Invasion_net_481.bnet
# Created BNet file: ./bnets/Invasion_net_482.bnet
# Created BNet file: ./bnets/Invasion_net_483.bnet
# Created BNet file: ./bnets/Invasion_net_484.bnet
# Created BNet file: ./bnets/Invasion_net_485.bnet
# Created BNet file: ./bnets/Invasion_net_486.bnet
# Created BNet file: ./bnets/Invasion_net_487.bnet
# Created BNet file: ./bnets/Invasion_net_488.bnet
# Created BNet file: ./bnets/Invasion_net_489.bnet
# Created BNet file: ./bnets/Invasion_net_490.bnet
# Created BNet file: ./bnets/Invasion_net_491.bnet
# Created BNet file: ./bnets/Invasion_net_492.bnet
# Created BNet file: ./bnets/Invasion_net_493.bnet
# Created BNet file: ./bnets/Invasion_net_494.bnet
# Created BNet file: ./bnets/Invasion_net_495.bnet
# Created BNet file: ./bnets/Invasion_net_496.bnet
# Created BNet file: ./bnets/Invasion_net_497.bnet
# Created BNet file: ./bnets/Invasion_net_498.bnet
# Created BNet file: ./bnets/Invasion_net_499.bnet
# Created BNet file: ./bnets/Invasion_net_500.bnet
# Created BNet file: ./bnets/Invasion_net_501.bnet
# Created BNet file: ./bnets/Invasion_net_502.bnet
# Created BNet file: ./bnets/Invasion_net_503.bnet
# Created BNet file: ./bnets/Invasion_net_504.bnet
# Created BNet file: ./bnets/Invasion_net_505.bnet
# Created BNet file: ./bnets/Invasion_net_506.bnet
# Created BNet file: ./bnets/Invasion_net_507.bnet
# Created BNet file: ./bnets/Invasion_net_508.bnet
# Created BNet file: ./bnets/Invasion_net_509.bnet
# Created BNet file: ./bnets/Invasion_net_510.bnet
# Created BNet file: ./bnets/Invasion_net_511.bnet
# Created BNet file: ./bnets/Invasion_net_512.bnet
# Created BNet file: ./bnets/Invasion_net_513.bnet
# Created BNet file: ./bnets/Invasion_net_514.bnet
# Created BNet file: ./bnets/Invasion_net_515.bnet
# Created BNet file: ./bnets/Invasion_net_516.bnet
# Created BNet file: ./bnets/Invasion_net_517.bnet
# Created BNet file: ./bnets/Invasion_net_518.bnet
# Created BNet file: ./bnets/Invasion_net_519.bnet
# Created BNet file: ./bnets/Invasion_net_520.bnet
# Created BNet file: ./bnets/Invasion_net_521.bnet
# Created BNet file: ./bnets/Invasion_net_522.bnet
# Created BNet file: ./bnets/Invasion_net_523.bnet
# Created BNet file: ./bnets/Invasion_net_524.bnet
# Created BNet file: ./bnets/Invasion_net_525.bnet
# Created BNet file: ./bnets/Invasion_net_526.bnet
# Created BNet file: ./bnets/Invasion_net_527.bnet
# Created BNet file: ./bnets/Invasion_net_528.bnet
# Created BNet file: ./bnets/Invasion_net_529.bnet
# Created BNet file: ./bnets/Invasion_net_530.bnet
# Created BNet file: ./bnets/Invasion_net_531.bnet
# Created BNet file: ./bnets/Invasion_net_532.bnet
# Created BNet file: ./bnets/Invasion_net_533.bnet
# Created BNet file: ./bnets/Invasion_net_534.bnet
# Created BNet file: ./bnets/Invasion_net_535.bnet
# Created BNet file: ./bnets/Invasion_net_536.bnet
# Created BNet file: ./bnets/Invasion_net_537.bnet
# Created BNet file: ./bnets/Invasion_net_538.bnet
# Created BNet file: ./bnets/Invasion_net_539.bnet
# Created BNet file: ./bnets/Invasion_net_540.bnet
# Created BNet file: ./bnets/Invasion_net_541.bnet
# Created BNet file: ./bnets/Invasion_net_542.bnet
# Created BNet file: ./bnets/Invasion_net_543.bnet
# Created BNet file: ./bnets/Invasion_net_544.bnet
# Created BNet file: ./bnets/Invasion_net_545.bnet
# Created BNet file: ./bnets/Invasion_net_546.bnet
# Created BNet file: ./bnets/Invasion_net_547.bnet
# Created BNet file: ./bnets/Invasion_net_548.bnet
# Created BNet file: ./bnets/Invasion_net_549.bnet
# Created BNet file: ./bnets/Invasion_net_550.bnet
# Created BNet file: ./bnets/Invasion_net_551.bnet
# Created BNet file: ./bnets/Invasion_net_552.bnet
# Created BNet file: ./bnets/Invasion_net_553.bnet
# Created BNet file: ./bnets/Invasion_net_554.bnet
# Created BNet file: ./bnets/Invasion_net_555.bnet
# Created BNet file: ./bnets/Invasion_net_556.bnet
# Created BNet file: ./bnets/Invasion_net_557.bnet
# Created BNet file: ./bnets/Invasion_net_558.bnet
# Created BNet file: ./bnets/Invasion_net_559.bnet
# Created BNet file: ./bnets/Invasion_net_560.bnet
# Created BNet file: ./bnets/Invasion_net_561.bnet
# Created BNet file: ./bnets/Invasion_net_562.bnet
# Created BNet file: ./bnets/Invasion_net_563.bnet
# Created BNet file: ./bnets/Invasion_net_564.bnet
# Created BNet file: ./bnets/Invasion_net_565.bnet
# Created BNet file: ./bnets/Invasion_net_566.bnet
# Created BNet file: ./bnets/Invasion_net_567.bnet
# Created BNet file: ./bnets/Invasion_net_568.bnet
# Created BNet file: ./bnets/Invasion_net_569.bnet
# Created BNet file: ./bnets/Invasion_net_570.bnet
# Created BNet file: ./bnets/Invasion_net_571.bnet
# Created BNet file: ./bnets/Invasion_net_572.bnet
# Created BNet file: ./bnets/Invasion_net_573.bnet
# Created BNet file: ./bnets/Invasion_net_574.bnet
# Created BNet file: ./bnets/Invasion_net_575.bnet
# Created BNet file: ./bnets/Invasion_net_576.bnet
# Created BNet file: ./bnets/Invasion_net_577.bnet
# Created BNet file: ./bnets/Invasion_net_578.bnet
# Created BNet file: ./bnets/Invasion_net_579.bnet
# Created BNet file: ./bnets/Invasion_net_580.bnet
# Created BNet file: ./bnets/Invasion_net_581.bnet
# Created BNet file: ./bnets/Invasion_net_582.bnet
# Created BNet file: ./bnets/Invasion_net_583.bnet
# Created BNet file: ./bnets/Invasion_net_584.bnet
# Created BNet file: ./bnets/Invasion_net_585.bnet
# Created BNet file: ./bnets/Invasion_net_586.bnet
# Created BNet file: ./bnets/Invasion_net_587.bnet
# Created BNet file: ./bnets/Invasion_net_588.bnet
# Created BNet file: ./bnets/Invasion_net_589.bnet
# Created BNet file: ./bnets/Invasion_net_590.bnet
# Created BNet file: ./bnets/Invasion_net_591.bnet
# Created BNet file: ./bnets/Invasion_net_592.bnet
# Created BNet file: ./bnets/Invasion_net_593.bnet
# Created BNet file: ./bnets/Invasion_net_594.bnet
# Created BNet file: ./bnets/Invasion_net_595.bnet
# Created BNet file: ./bnets/Invasion_net_596.bnet
# Created BNet file: ./bnets/Invasion_net_597.bnet
# Created BNet file: ./bnets/Invasion_net_598.bnet
# Created BNet file: ./bnets/Invasion_net_599.bnet
# Created BNet file: ./bnets/Invasion_net_600.bnet
# Created BNet file: ./bnets/Invasion_net_601.bnet
# Created BNet file: ./bnets/Invasion_net_602.bnet
# Created BNet file: ./bnets/Invasion_net_603.bnet
# Created BNet file: ./bnets/Invasion_net_604.bnet
# Created BNet file: ./bnets/Invasion_net_605.bnet
# Created BNet file: ./bnets/Invasion_net_606.bnet
# Created BNet file: ./bnets/Invasion_net_607.bnet
# Created BNet file: ./bnets/Invasion_net_608.bnet
# Created BNet file: ./bnets/Invasion_net_609.bnet
# Created BNet file: ./bnets/Invasion_net_610.bnet
# Created BNet file: ./bnets/Invasion_net_611.bnet
# Created BNet file: ./bnets/Invasion_net_612.bnet
# Created BNet file: ./bnets/Invasion_net_613.bnet
# Created BNet file: ./bnets/Invasion_net_614.bnet
# Created BNet file: ./bnets/Invasion_net_615.bnet
# Created BNet file: ./bnets/Invasion_net_616.bnet
# Created BNet file: ./bnets/Invasion_net_617.bnet
# Created BNet file: ./bnets/Invasion_net_618.bnet
# Created BNet file: ./bnets/Invasion_net_619.bnet
# Created BNet file: ./bnets/Invasion_net_620.bnet
# Created BNet file: ./bnets/Invasion_net_621.bnet
# Created BNet file: ./bnets/Invasion_net_622.bnet
# Created BNet file: ./bnets/Invasion_net_623.bnet
# Created BNet file: ./bnets/Invasion_net_624.bnet
# Created BNet file: ./bnets/Invasion_net_625.bnet
# Created BNet file: ./bnets/Invasion_net_626.bnet
# Created BNet file: ./bnets/Invasion_net_627.bnet
# Created BNet file: ./bnets/Invasion_net_628.bnet
# Created BNet file: ./bnets/Invasion_net_629.bnet
# Created BNet file: ./bnets/Invasion_net_630.bnet
# Created BNet file: ./bnets/Invasion_net_631.bnet
# Created BNet file: ./bnets/Invasion_net_632.bnet
# Created BNet file: ./bnets/Invasion_net_633.bnet
# Created BNet file: ./bnets/Invasion_net_634.bnet
# Created BNet file: ./bnets/Invasion_net_635.bnet
# Created BNet file: ./bnets/Invasion_net_636.bnet
# Created BNet file: ./bnets/Invasion_net_637.bnet
# Created BNet file: ./bnets/Invasion_net_638.bnet
# Created BNet file: ./bnets/Invasion_net_639.bnet
# Created BNet file: ./bnets/Invasion_net_640.bnet
# Created BNet file: ./bnets/Invasion_net_641.bnet
# Created BNet file: ./bnets/Invasion_net_642.bnet
# Created BNet file: ./bnets/Invasion_net_643.bnet
# Created BNet file: ./bnets/Invasion_net_644.bnet
# Created BNet file: ./bnets/Invasion_net_645.bnet
# Created BNet file: ./bnets/Invasion_net_646.bnet
# Created BNet file: ./bnets/Invasion_net_647.bnet
# Created BNet file: ./bnets/Invasion_net_648.bnet
# Created BNet file: ./bnets/Invasion_net_649.bnet
# Created BNet file: ./bnets/Invasion_net_650.bnet
# Created BNet file: ./bnets/Invasion_net_651.bnet
# Created BNet file: ./bnets/Invasion_net_652.bnet
# Created BNet file: ./bnets/Invasion_net_653.bnet
# Created BNet file: ./bnets/Invasion_net_654.bnet
# Created BNet file: ./bnets/Invasion_net_655.bnet
# Created BNet file: ./bnets/Invasion_net_656.bnet
# Created BNet file: ./bnets/Invasion_net_657.bnet
# Created BNet file: ./bnets/Invasion_net_658.bnet
# Created BNet file: ./bnets/Invasion_net_659.bnet
# Created BNet file: ./bnets/Invasion_net_660.bnet
# Created BNet file: ./bnets/Invasion_net_661.bnet
# Created BNet file: ./bnets/Invasion_net_662.bnet
# Created BNet file: ./bnets/Invasion_net_663.bnet
# Created BNet file: ./bnets/Invasion_net_664.bnet
# Created BNet file: ./bnets/Invasion_net_665.bnet
# Created BNet file: ./bnets/Invasion_net_666.bnet
# Created BNet file: ./bnets/Invasion_net_667.bnet
# Created BNet file: ./bnets/Invasion_net_668.bnet
# Created BNet file: ./bnets/Invasion_net_669.bnet
# Created BNet file: ./bnets/Invasion_net_670.bnet
# Created BNet file: ./bnets/Invasion_net_671.bnet
# Created BNet file: ./bnets/Invasion_net_672.bnet
# Created BNet file: ./bnets/Invasion_net_673.bnet
# Created BNet file: ./bnets/Invasion_net_674.bnet
# Created BNet file: ./bnets/Invasion_net_675.bnet
# Created BNet file: ./bnets/Invasion_net_676.bnet
# Created BNet file: ./bnets/Invasion_net_677.bnet
# Created BNet file: ./bnets/Invasion_net_678.bnet
# Created BNet file: ./bnets/Invasion_net_679.bnet
# Created BNet file: ./bnets/Invasion_net_680.bnet
# Created BNet file: ./bnets/Invasion_net_681.bnet
# Created BNet file: ./bnets/Invasion_net_682.bnet
# Created BNet file: ./bnets/Invasion_net_683.bnet
# Created BNet file: ./bnets/Invasion_net_684.bnet
# Created BNet file: ./bnets/Invasion_net_685.bnet
# Created BNet file: ./bnets/Invasion_net_686.bnet
# Created BNet file: ./bnets/Invasion_net_687.bnet
# Created BNet file: ./bnets/Invasion_net_688.bnet
# Created BNet file: ./bnets/Invasion_net_689.bnet
# Created BNet file: ./bnets/Invasion_net_690.bnet
# Created BNet file: ./bnets/Invasion_net_691.bnet
# Created BNet file: ./bnets/Invasion_net_692.bnet
# Created BNet file: ./bnets/Invasion_net_693.bnet
# Created BNet file: ./bnets/Invasion_net_694.bnet
# Created BNet file: ./bnets/Invasion_net_695.bnet
# Created BNet file: ./bnets/Invasion_net_696.bnet
# Created BNet file: ./bnets/Invasion_net_697.bnet
# Created BNet file: ./bnets/Invasion_net_698.bnet
# Created BNet file: ./bnets/Invasion_net_699.bnet
# Created BNet file: ./bnets/Invasion_net_700.bnet
# Created BNet file: ./bnets/Invasion_net_701.bnet
# Created BNet file: ./bnets/Invasion_net_702.bnet
# Created BNet file: ./bnets/Invasion_net_703.bnet
# Created BNet file: ./bnets/Invasion_net_704.bnet
# Created BNet file: ./bnets/Invasion_net_705.bnet
# Created BNet file: ./bnets/Invasion_net_706.bnet
# Created BNet file: ./bnets/Invasion_net_707.bnet
# Created BNet file: ./bnets/Invasion_net_708.bnet
# Created BNet file: ./bnets/Invasion_net_709.bnet
# Created BNet file: ./bnets/Invasion_net_710.bnet
# Created BNet file: ./bnets/Invasion_net_711.bnet
# Created BNet file: ./bnets/Invasion_net_712.bnet
# Created BNet file: ./bnets/Invasion_net_713.bnet
# Created BNet file: ./bnets/Invasion_net_714.bnet
# Created BNet file: ./bnets/Invasion_net_715.bnet
# Created BNet file: ./bnets/Invasion_net_716.bnet
# Created BNet file: ./bnets/Invasion_net_717.bnet
# Created BNet file: ./bnets/Invasion_net_718.bnet
# Created BNet file: ./bnets/Invasion_net_719.bnet
# Created BNet file: ./bnets/Invasion_net_720.bnet
# Created BNet file: ./bnets/Invasion_net_721.bnet
# Created BNet file: ./bnets/Invasion_net_722.bnet
# Created BNet file: ./bnets/Invasion_net_723.bnet
# Created BNet file: ./bnets/Invasion_net_724.bnet
# Created BNet file: ./bnets/Invasion_net_725.bnet
# Created BNet file: ./bnets/Invasion_net_726.bnet
# Created BNet file: ./bnets/Invasion_net_727.bnet
# Created BNet file: ./bnets/Invasion_net_728.bnet
# Created BNet file: ./bnets/Invasion_net_729.bnet
# Created BNet file: ./bnets/Invasion_net_730.bnet
# Created BNet file: ./bnets/Invasion_net_731.bnet
# Created BNet file: ./bnets/Invasion_net_732.bnet
# Created BNet file: ./bnets/Invasion_net_733.bnet
# Created BNet file: ./bnets/Invasion_net_734.bnet
# Created BNet file: ./bnets/Invasion_net_735.bnet
# Created BNet file: ./bnets/Invasion_net_736.bnet
# Created BNet file: ./bnets/Invasion_net_737.bnet
# Created BNet file: ./bnets/Invasion_net_738.bnet
# Created BNet file: ./bnets/Invasion_net_739.bnet
# Created BNet file: ./bnets/Invasion_net_740.bnet
# Created BNet file: ./bnets/Invasion_net_741.bnet
# Created BNet file: ./bnets/Invasion_net_742.bnet
# Created BNet file: ./bnets/Invasion_net_743.bnet
# Created BNet file: ./bnets/Invasion_net_744.bnet
# Created BNet file: ./bnets/Invasion_net_745.bnet
# Created BNet file: ./bnets/Invasion_net_746.bnet
# Created BNet file: ./bnets/Invasion_net_747.bnet
# Created BNet file: ./bnets/Invasion_net_748.bnet
# Created BNet file: ./bnets/Invasion_net_749.bnet
# Created BNet file: ./bnets/Invasion_net_750.bnet
# Created BNet file: ./bnets/Invasion_net_751.bnet
# Created BNet file: ./bnets/Invasion_net_752.bnet
# Created BNet file: ./bnets/Invasion_net_753.bnet
# Created BNet file: ./bnets/Invasion_net_754.bnet
# Created BNet file: ./bnets/Invasion_net_755.bnet
# Created BNet file: ./bnets/Invasion_net_756.bnet
# Created BNet file: ./bnets/Invasion_net_757.bnet
# Created BNet file: ./bnets/Invasion_net_758.bnet
# Created BNet file: ./bnets/Invasion_net_759.bnet
# Created BNet file: ./bnets/Invasion_net_760.bnet
# Created BNet file: ./bnets/Invasion_net_761.bnet
# Created BNet file: ./bnets/Invasion_net_762.bnet
# Created BNet file: ./bnets/Invasion_net_763.bnet
# Created BNet file: ./bnets/Invasion_net_764.bnet
# Created BNet file: ./bnets/Invasion_net_765.bnet
# Created BNet file: ./bnets/Invasion_net_766.bnet
# Created BNet file: ./bnets/Invasion_net_767.bnet
# Created BNet file: ./bnets/Invasion_net_768.bnet
# Created BNet file: ./bnets/Invasion_net_769.bnet
# Created BNet file: ./bnets/Invasion_net_770.bnet
# Created BNet file: ./bnets/Invasion_net_771.bnet
# Created BNet file: ./bnets/Invasion_net_772.bnet
# Created BNet file: ./bnets/Invasion_net_773.bnet
# Created BNet file: ./bnets/Invasion_net_774.bnet
# Created BNet file: ./bnets/Invasion_net_775.bnet
# Created BNet file: ./bnets/Invasion_net_776.bnet
# Created BNet file: ./bnets/Invasion_net_777.bnet
# Created BNet file: ./bnets/Invasion_net_778.bnet
# Created BNet file: ./bnets/Invasion_net_779.bnet
# Created BNet file: ./bnets/Invasion_net_780.bnet
# Created BNet file: ./bnets/Invasion_net_781.bnet
# Created BNet file: ./bnets/Invasion_net_782.bnet
# Created BNet file: ./bnets/Invasion_net_783.bnet
# Created BNet file: ./bnets/Invasion_net_784.bnet
# Created BNet file: ./bnets/Invasion_net_785.bnet
# Created BNet file: ./bnets/Invasion_net_786.bnet
# Created BNet file: ./bnets/Invasion_net_787.bnet
# Created BNet file: ./bnets/Invasion_net_788.bnet
# Created BNet file: ./bnets/Invasion_net_789.bnet
# Created BNet file: ./bnets/Invasion_net_790.bnet
# Created BNet file: ./bnets/Invasion_net_791.bnet
# Created BNet file: ./bnets/Invasion_net_792.bnet
# Created BNet file: ./bnets/Invasion_net_793.bnet
# Created BNet file: ./bnets/Invasion_net_794.bnet
# Created BNet file: ./bnets/Invasion_net_795.bnet
# Created BNet file: ./bnets/Invasion_net_796.bnet
# Created BNet file: ./bnets/Invasion_net_797.bnet
# Created BNet file: ./bnets/Invasion_net_798.bnet
# Created BNet file: ./bnets/Invasion_net_799.bnet
# Created BNet file: ./bnets/Invasion_net_800.bnet
# Created BNet file: ./bnets/Invasion_net_801.bnet
# Created BNet file: ./bnets/Invasion_net_802.bnet
# Created BNet file: ./bnets/Invasion_net_803.bnet
# Created BNet file: ./bnets/Invasion_net_804.bnet
# Created BNet file: ./bnets/Invasion_net_805.bnet
# Created BNet file: ./bnets/Invasion_net_806.bnet
# Created BNet file: ./bnets/Invasion_net_807.bnet
# Created BNet file: ./bnets/Invasion_net_808.bnet
# Created BNet file: ./bnets/Invasion_net_809.bnet
# Created BNet file: ./bnets/Invasion_net_810.bnet
# Created BNet file: ./bnets/Invasion_net_811.bnet
# Created BNet file: ./bnets/Invasion_net_812.bnet
# Created BNet file: ./bnets/Invasion_net_813.bnet
# Created BNet file: ./bnets/Invasion_net_814.bnet
# Created BNet file: ./bnets/Invasion_net_815.bnet
# Created BNet file: ./bnets/Invasion_net_816.bnet
# Created BNet file: ./bnets/Invasion_net_817.bnet
# Created BNet file: ./bnets/Invasion_net_818.bnet
# Created BNet file: ./bnets/Invasion_net_819.bnet
# Created BNet file: ./bnets/Invasion_net_820.bnet
# Created BNet file: ./bnets/Invasion_net_821.bnet
# Created BNet file: ./bnets/Invasion_net_822.bnet
# Created BNet file: ./bnets/Invasion_net_823.bnet
# Created BNet file: ./bnets/Invasion_net_824.bnet
# Created BNet file: ./bnets/Invasion_net_825.bnet
# Created BNet file: ./bnets/Invasion_net_826.bnet
# Created BNet file: ./bnets/Invasion_net_827.bnet
# Created BNet file: ./bnets/Invasion_net_828.bnet
# Created BNet file: ./bnets/Invasion_net_829.bnet
# Created BNet file: ./bnets/Invasion_net_830.bnet
# Created BNet file: ./bnets/Invasion_net_831.bnet
# Created BNet file: ./bnets/Invasion_net_832.bnet
# Created BNet file: ./bnets/Invasion_net_833.bnet
# Created BNet file: ./bnets/Invasion_net_834.bnet
# Created BNet file: ./bnets/Invasion_net_835.bnet
# Created BNet file: ./bnets/Invasion_net_836.bnet
# Created BNet file: ./bnets/Invasion_net_837.bnet
# Created BNet file: ./bnets/Invasion_net_838.bnet
# Created BNet file: ./bnets/Invasion_net_839.bnet
# Created BNet file: ./bnets/Invasion_net_840.bnet
# Created BNet file: ./bnets/Invasion_net_841.bnet
# Created BNet file: ./bnets/Invasion_net_842.bnet
# Created BNet file: ./bnets/Invasion_net_843.bnet
# Created BNet file: ./bnets/Invasion_net_844.bnet
# Created BNet file: ./bnets/Invasion_net_845.bnet
# Created BNet file: ./bnets/Invasion_net_846.bnet
# Created BNet file: ./bnets/Invasion_net_847.bnet
# Created BNet file: ./bnets/Invasion_net_848.bnet
# Created BNet file: ./bnets/Invasion_net_849.bnet
# Created BNet file: ./bnets/Invasion_net_850.bnet
# Created BNet file: ./bnets/Invasion_net_851.bnet
# Created BNet file: ./bnets/Invasion_net_852.bnet
# Created BNet file: ./bnets/Invasion_net_853.bnet
# Created BNet file: ./bnets/Invasion_net_854.bnet
# Created BNet file: ./bnets/Invasion_net_855.bnet
# Created BNet file: ./bnets/Invasion_net_856.bnet
# Created BNet file: ./bnets/Invasion_net_857.bnet
# Created BNet file: ./bnets/Invasion_net_858.bnet
# Created BNet file: ./bnets/Invasion_net_859.bnet
# Created BNet file: ./bnets/Invasion_net_860.bnet
# Created BNet file: ./bnets/Invasion_net_861.bnet
# Created BNet file: ./bnets/Invasion_net_862.bnet
# Created BNet file: ./bnets/Invasion_net_863.bnet
# Created BNet file: ./bnets/Invasion_net_864.bnet
# Created BNet file: ./bnets/Invasion_net_865.bnet
# Created BNet file: ./bnets/Invasion_net_866.bnet
# Created BNet file: ./bnets/Invasion_net_867.bnet
# Created BNet file: ./bnets/Invasion_net_868.bnet
# Created BNet file: ./bnets/Invasion_net_869.bnet
# Created BNet file: ./bnets/Invasion_net_870.bnet
# Created BNet file: ./bnets/Invasion_net_871.bnet
# Created BNet file: ./bnets/Invasion_net_872.bnet
# Created BNet file: ./bnets/Invasion_net_873.bnet
# Created BNet file: ./bnets/Invasion_net_874.bnet
# Created BNet file: ./bnets/Invasion_net_875.bnet
# Created BNet file: ./bnets/Invasion_net_876.bnet
# Created BNet file: ./bnets/Invasion_net_877.bnet
# Created BNet file: ./bnets/Invasion_net_878.bnet
# Created BNet file: ./bnets/Invasion_net_879.bnet
# Created BNet file: ./bnets/Invasion_net_880.bnet
# Created BNet file: ./bnets/Invasion_net_881.bnet
# Created BNet file: ./bnets/Invasion_net_882.bnet
# Created BNet file: ./bnets/Invasion_net_883.bnet
# Created BNet file: ./bnets/Invasion_net_884.bnet
# Created BNet file: ./bnets/Invasion_net_885.bnet
# Created BNet file: ./bnets/Invasion_net_886.bnet
# Created BNet file: ./bnets/Invasion_net_887.bnet
# Created BNet file: ./bnets/Invasion_net_888.bnet
# Created BNet file: ./bnets/Invasion_net_889.bnet
# Created BNet file: ./bnets/Invasion_net_890.bnet
# Created BNet file: ./bnets/Invasion_net_891.bnet
# Created BNet file: ./bnets/Invasion_net_892.bnet
# Created BNet file: ./bnets/Invasion_net_893.bnet
# Created BNet file: ./bnets/Invasion_net_894.bnet
# Created BNet file: ./bnets/Invasion_net_895.bnet
# Created BNet file: ./bnets/Invasion_net_896.bnet
# Created BNet file: ./bnets/Invasion_net_897.bnet
# Created BNet file: ./bnets/Invasion_net_898.bnet
# Created BNet file: ./bnets/Invasion_net_899.bnet
# Created BNet file: ./bnets/Invasion_net_900.bnet
# Created BNet file: ./bnets/Invasion_net_901.bnet
# Created BNet file: ./bnets/Invasion_net_902.bnet
# Created BNet file: ./bnets/Invasion_net_903.bnet
# Created BNet file: ./bnets/Invasion_net_904.bnet
# Created BNet file: ./bnets/Invasion_net_905.bnet
# Created BNet file: ./bnets/Invasion_net_906.bnet
# Created BNet file: ./bnets/Invasion_net_907.bnet
# Created BNet file: ./bnets/Invasion_net_908.bnet
# Created BNet file: ./bnets/Invasion_net_909.bnet
# Created BNet file: ./bnets/Invasion_net_910.bnet
# Created BNet file: ./bnets/Invasion_net_911.bnet
# Created BNet file: ./bnets/Invasion_net_912.bnet
# Created BNet file: ./bnets/Invasion_net_913.bnet
# Created BNet file: ./bnets/Invasion_net_914.bnet
# Created BNet file: ./bnets/Invasion_net_915.bnet
# Created BNet file: ./bnets/Invasion_net_916.bnet
# Created BNet file: ./bnets/Invasion_net_917.bnet
# Created BNet file: ./bnets/Invasion_net_918.bnet
# Created BNet file: ./bnets/Invasion_net_919.bnet
# Created BNet file: ./bnets/Invasion_net_920.bnet
# Created BNet file: ./bnets/Invasion_net_921.bnet
# Created BNet file: ./bnets/Invasion_net_922.bnet
# Created BNet file: ./bnets/Invasion_net_923.bnet
# Created BNet file: ./bnets/Invasion_net_924.bnet
# Created BNet file: ./bnets/Invasion_net_925.bnet
# Created BNet file: ./bnets/Invasion_net_926.bnet
# Created BNet file: ./bnets/Invasion_net_927.bnet
# Created BNet file: ./bnets/Invasion_net_928.bnet
# Created BNet file: ./bnets/Invasion_net_929.bnet
# Created BNet file: ./bnets/Invasion_net_930.bnet
# Created BNet file: ./bnets/Invasion_net_931.bnet
# Created BNet file: ./bnets/Invasion_net_932.bnet
# Created BNet file: ./bnets/Invasion_net_933.bnet
# Created BNet file: ./bnets/Invasion_net_934.bnet
# Created BNet file: ./bnets/Invasion_net_935.bnet
# Created BNet file: ./bnets/Invasion_net_936.bnet
# Created BNet file: ./bnets/Invasion_net_937.bnet
# Created BNet file: ./bnets/Invasion_net_938.bnet
# Created BNet file: ./bnets/Invasion_net_939.bnet
# Created BNet file: ./bnets/Invasion_net_940.bnet
# Created BNet file: ./bnets/Invasion_net_941.bnet
# Created BNet file: ./bnets/Invasion_net_942.bnet
# Created BNet file: ./bnets/Invasion_net_943.bnet
# Created BNet file: ./bnets/Invasion_net_944.bnet
# Created BNet file: ./bnets/Invasion_net_945.bnet
# Created BNet file: ./bnets/Invasion_net_946.bnet
# Created BNet file: ./bnets/Invasion_net_947.bnet
# Created BNet file: ./bnets/Invasion_net_948.bnet
# Created BNet file: ./bnets/Invasion_net_949.bnet
# Created BNet file: ./bnets/Invasion_net_950.bnet
# Created BNet file: ./bnets/Invasion_net_951.bnet
# Created BNet file: ./bnets/Invasion_net_952.bnet
# Created BNet file: ./bnets/Invasion_net_953.bnet
# Created BNet file: ./bnets/Invasion_net_954.bnet
# Created BNet file: ./bnets/Invasion_net_955.bnet
# Created BNet file: ./bnets/Invasion_net_956.bnet
# Created BNet file: ./bnets/Invasion_net_957.bnet
# Created BNet file: ./bnets/Invasion_net_958.bnet
# Created BNet file: ./bnets/Invasion_net_959.bnet
# Created BNet file: ./bnets/Invasion_net_960.bnet
# Created BNet file: ./bnets/Invasion_net_961.bnet
# Created BNet file: ./bnets/Invasion_net_962.bnet
# Created BNet file: ./bnets/Invasion_net_963.bnet
# Created BNet file: ./bnets/Invasion_net_964.bnet
# Created BNet file: ./bnets/Invasion_net_965.bnet
# Created BNet file: ./bnets/Invasion_net_966.bnet
# Created BNet file: ./bnets/Invasion_net_967.bnet
# ...
# Created BNet file: ./bnets/Invasion_net_7874.bnet
# Created BNet file: ./bnets/Invasion_net_7875.bnet
# Created BNet file: ./bnets/Invasion_net_7876.bnet
# Created BNet file: ./bnets/Invasion_net_7877.bnet
# Created BNet file: ./bnets/Invasion_net_7878.bnet
# Created BNet file: ./bnets/Invasion_net_7879.bnet
# Created BNet file: ./bnets/Invasion_net_7880.bnet
# Created BNet file: ./bnets/Invasion_net_7881.bnet
# Created BNet file: ./bnets/Invasion_net_7882.bnet
# Created BNet file: ./bnets/Invasion_net_7883.bnet
# Created BNet file: ./bnets/Invasion_net_7884.bnet
# Created BNet file: ./bnets/Invasion_net_7885.bnet
# Created BNet file: ./bnets/Invasion_net_7886.bnet
# Created BNet file: ./bnets/Invasion_net_7887.bnet
# Created BNet file: ./bnets/Invasion_net_7888.bnet
# Created BNet file: ./bnets/Invasion_net_7889.bnet
# Created BNet file: ./bnets/Invasion_net_7890.bnet
# Created BNet file: ./bnets/Invasion_net_7891.bnet
# Created BNet file: ./bnets/Invasion_net_7892.bnet
# Created BNet file: ./bnets/Invasion_net_7893.bnet
# Created BNet file: ./bnets/Invasion_net_7894.bnet
# Created BNet file: ./bnets/Invasion_net_7895.bnet
# Created BNet file: ./bnets/Invasion_net_7896.bnet
# Created BNet file: ./bnets/Invasion_net_7897.bnet
# Created BNet file: ./bnets/Invasion_net_7898.bnet
# Created BNet file: ./bnets/Invasion_net_7899.bnet
# Created BNet file: ./bnets/Invasion_net_7900.bnet
# Created BNet file: ./bnets/Invasion_net_7901.bnet
# Created BNet file: ./bnets/Invasion_net_7902.bnet
# Created BNet file: ./bnets/Invasion_net_7903.bnet
# Created BNet file: ./bnets/Invasion_net_7904.bnet
# Created BNet file: ./bnets/Invasion_net_7905.bnet
# Created BNet file: ./bnets/Invasion_net_7906.bnet
# Created BNet file: ./bnets/Invasion_net_7907.bnet
# Created BNet file: ./bnets/Invasion_net_7908.bnet
# Created BNet file: ./bnets/Invasion_net_7909.bnet
# Created BNet file: ./bnets/Invasion_net_7910.bnet
# Created BNet file: ./bnets/Invasion_net_7911.bnet
# Created BNet file: ./bnets/Invasion_net_7912.bnet
# Created BNet file: ./bnets/Invasion_net_7913.bnet
# Created BNet file: ./bnets/Invasion_net_7914.bnet
# Created BNet file: ./bnets/Invasion_net_7915.bnet
# Created BNet file: ./bnets/Invasion_net_7916.bnet
# Created BNet file: ./bnets/Invasion_net_7917.bnet
# Created BNet file: ./bnets/Invasion_net_7918.bnet
# Created BNet file: ./bnets/Invasion_net_7919.bnet
# Created BNet file: ./bnets/Invasion_net_7920.bnet
# Created BNet file: ./bnets/Invasion_net_7921.bnet
# Created BNet file: ./bnets/Invasion_net_7922.bnet
# Created BNet file: ./bnets/Invasion_net_7923.bnet
# Created BNet file: ./bnets/Invasion_net_7924.bnet
# Created BNet file: ./bnets/Invasion_net_7925.bnet
# Created BNet file: ./bnets/Invasion_net_7926.bnet
# Created BNet file: ./bnets/Invasion_net_7927.bnet
# Created BNet file: ./bnets/Invasion_net_7928.bnet
# Created BNet file: ./bnets/Invasion_net_7929.bnet
# Created BNet file: ./bnets/Invasion_net_7930.bnet
# Created BNet file: ./bnets/Invasion_net_7931.bnet
# Created BNet file: ./bnets/Invasion_net_7932.bnet
# Created BNet file: ./bnets/Invasion_net_7933.bnet
# Created BNet file: ./bnets/Invasion_net_7934.bnet
# Created BNet file: ./bnets/Invasion_net_7935.bnet
# Created BNet file: ./bnets/Invasion_net_7936.bnet
# Created BNet file: ./bnets/Invasion_net_7937.bnet
# Created BNet file: ./bnets/Invasion_net_7938.bnet
# Created BNet file: ./bnets/Invasion_net_7939.bnet
# Created BNet file: ./bnets/Invasion_net_7940.bnet
# Created BNet file: ./bnets/Invasion_net_7941.bnet
# Created BNet file: ./bnets/Invasion_net_7942.bnet
# Created BNet file: ./bnets/Invasion_net_7943.bnet
# Created BNet file: ./bnets/Invasion_net_7944.bnet
# Created BNet file: ./bnets/Invasion_net_7945.bnet
# Created BNet file: ./bnets/Invasion_net_7946.bnet
# Created BNet file: ./bnets/Invasion_net_7947.bnet
# Created BNet file: ./bnets/Invasion_net_7948.bnet
# Created BNet file: ./bnets/Invasion_net_7949.bnet
# Created BNet file: ./bnets/Invasion_net_7950.bnet
# Created BNet file: ./bnets/Invasion_net_7951.bnet
# Created BNet file: ./bnets/Invasion_net_7952.bnet
# Created BNet file: ./bnets/Invasion_net_7953.bnet
# Created BNet file: ./bnets/Invasion_net_7954.bnet
# Created BNet file: ./bnets/Invasion_net_7955.bnet
# Created BNet file: ./bnets/Invasion_net_7956.bnet
# Created BNet file: ./bnets/Invasion_net_7957.bnet
# Created BNet file: ./bnets/Invasion_net_7958.bnet
# Created BNet file: ./bnets/Invasion_net_7959.bnet
# Created BNet file: ./bnets/Invasion_net_7960.bnet
# Created BNet file: ./bnets/Invasion_net_7961.bnet
# Created BNet file: ./bnets/Invasion_net_7962.bnet
# Created BNet file: ./bnets/Invasion_net_7963.bnet
# Created BNet file: ./bnets/Invasion_net_7964.bnet
# Created BNet file: ./bnets/Invasion_net_7965.bnet
# Created BNet file: ./bnets/Invasion_net_7966.bnet
# Created BNet file: ./bnets/Invasion_net_7967.bnet
# Created BNet file: ./bnets/Invasion_net_7968.bnet
# Created BNet file: ./bnets/Invasion_net_7969.bnet
# Created BNet file: ./bnets/Invasion_net_7970.bnet
# Created BNet file: ./bnets/Invasion_net_7971.bnet
# Created BNet file: ./bnets/Invasion_net_7972.bnet
# Created BNet file: ./bnets/Invasion_net_7973.bnet
# Created BNet file: ./bnets/Invasion_net_7974.bnet
# Created BNet file: ./bnets/Invasion_net_7975.bnet
# Created BNet file: ./bnets/Invasion_net_7976.bnet
# Created BNet file: ./bnets/Invasion_net_7977.bnet
# Created BNet file: ./bnets/Invasion_net_7978.bnet
# Created BNet file: ./bnets/Invasion_net_7979.bnet
# Created BNet file: ./bnets/Invasion_net_7980.bnet
# Created BNet file: ./bnets/Invasion_net_7981.bnet
# Created BNet file: ./bnets/Invasion_net_7982.bnet
# Created BNet file: ./bnets/Invasion_net_7983.bnet
# Created BNet file: ./bnets/Invasion_net_7984.bnet
# Created BNet file: ./bnets/Invasion_net_7985.bnet
# Created BNet file: ./bnets/Invasion_net_7986.bnet
# Created BNet file: ./bnets/Invasion_net_7987.bnet
# Created BNet file: ./bnets/Invasion_net_7988.bnet
# Created BNet file: ./bnets/Invasion_net_7989.bnet
# Created BNet file: ./bnets/Invasion_net_7990.bnet
# Created BNet file: ./bnets/Invasion_net_7991.bnet
# Created BNet file: ./bnets/Invasion_net_7992.bnet
# Created BNet file: ./bnets/Invasion_net_7993.bnet
# Created BNet file: ./bnets/Invasion_net_7994.bnet
# Created BNet file: ./bnets/Invasion_net_7995.bnet
# Created BNet file: ./bnets/Invasion_net_7996.bnet
# Created BNet file: ./bnets/Invasion_net_7997.bnet
# Created BNet file: ./bnets/Invasion_net_7998.bnet
# Created BNet file: ./bnets/Invasion_net_7999.bnet
# Created BNet file: ./bnets/Invasion_net_8000.bnet
# Created BNet file: ./bnets/Invasion_net_8001.bnet
# Created BNet file: ./bnets/Invasion_net_8002.bnet
# Created BNet file: ./bnets/Invasion_net_8003.bnet
# Created BNet file: ./bnets/Invasion_net_8004.bnet
# Created BNet file: ./bnets/Invasion_net_8005.bnet
# Created BNet file: ./bnets/Invasion_net_8006.bnet
# Created BNet file: ./bnets/Invasion_net_8007.bnet
# Created BNet file: ./bnets/Invasion_net_8008.bnet
# Created BNet file: ./bnets/Invasion_net_8009.bnet
# Created BNet file: ./bnets/Invasion_net_8010.bnet
# Created BNet file: ./bnets/Invasion_net_8011.bnet
# Created BNet file: ./bnets/Invasion_net_8012.bnet
# Created BNet file: ./bnets/Invasion_net_8013.bnet
# Created BNet file: ./bnets/Invasion_net_8014.bnet
# Created BNet file: ./bnets/Invasion_net_8015.bnet
# Created BNet file: ./bnets/Invasion_net_8016.bnet
# Created BNet file: ./bnets/Invasion_net_8017.bnet
# Created BNet file: ./bnets/Invasion_net_8018.bnet
# Created BNet file: ./bnets/Invasion_net_8019.bnet
# Created BNet file: ./bnets/Invasion_net_8020.bnet
# Created BNet file: ./bnets/Invasion_net_8021.bnet
# Created BNet file: ./bnets/Invasion_net_8022.bnet
# Created BNet file: ./bnets/Invasion_net_8023.bnet
# Created BNet file: ./bnets/Invasion_net_8024.bnet
# Created BNet file: ./bnets/Invasion_net_8025.bnet
# Created BNet file: ./bnets/Invasion_net_8026.bnet
# Created BNet file: ./bnets/Invasion_net_8027.bnet
# Created BNet file: ./bnets/Invasion_net_8028.bnet
# Created BNet file: ./bnets/Invasion_net_8029.bnet
# Created BNet file: ./bnets/Invasion_net_8030.bnet
# Created BNet file: ./bnets/Invasion_net_8031.bnet
# Created BNet file: ./bnets/Invasion_net_8032.bnet
# Created BNet file: ./bnets/Invasion_net_8033.bnet
# Created BNet file: ./bnets/Invasion_net_8034.bnet
# Created BNet file: ./bnets/Invasion_net_8035.bnet
# Created BNet file: ./bnets/Invasion_net_8036.bnet
# Created BNet file: ./bnets/Invasion_net_8037.bnet
# Created BNet file: ./bnets/Invasion_net_8038.bnet
# Created BNet file: ./bnets/Invasion_net_8039.bnet
# Created BNet file: ./bnets/Invasion_net_8040.bnet
# Created BNet file: ./bnets/Invasion_net_8041.bnet
# Created BNet file: ./bnets/Invasion_net_8042.bnet
# Created BNet file: ./bnets/Invasion_net_8043.bnet
# Created BNet file: ./bnets/Invasion_net_8044.bnet
# Created BNet file: ./bnets/Invasion_net_8045.bnet
# Created BNet file: ./bnets/Invasion_net_8046.bnet
# Created BNet file: ./bnets/Invasion_net_8047.bnet
# Created BNet file: ./bnets/Invasion_net_8048.bnet
# Created BNet file: ./bnets/Invasion_net_8049.bnet
# Created BNet file: ./bnets/Invasion_net_8050.bnet
# Created BNet file: ./bnets/Invasion_net_8051.bnet
# Created BNet file: ./bnets/Invasion_net_8052.bnet
# Created BNet file: ./bnets/Invasion_net_8053.bnet
# Created BNet file: ./bnets/Invasion_net_8054.bnet
# Created BNet file: ./bnets/Invasion_net_8055.bnet
# Created BNet file: ./bnets/Invasion_net_8056.bnet
# Created BNet file: ./bnets/Invasion_net_8057.bnet
# Created BNet file: ./bnets/Invasion_net_8058.bnet
# Created BNet file: ./bnets/Invasion_net_8059.bnet
# Created BNet file: ./bnets/Invasion_net_8060.bnet
# Created BNet file: ./bnets/Invasion_net_8061.bnet
# Created BNet file: ./bnets/Invasion_net_8062.bnet
# Created BNet file: ./bnets/Invasion_net_8063.bnet
# Created BNet file: ./bnets/Invasion_net_8064.bnet
# Created BNet file: ./bnets/Invasion_net_8065.bnet
# Created BNet file: ./bnets/Invasion_net_8066.bnet
# Created BNet file: ./bnets/Invasion_net_8067.bnet
# Created BNet file: ./bnets/Invasion_net_8068.bnet
# Created BNet file: ./bnets/Invasion_net_8069.bnet
# Created BNet file: ./bnets/Invasion_net_8070.bnet
# Created BNet file: ./bnets/Invasion_net_8071.bnet
# Created BNet file: ./bnets/Invasion_net_8072.bnet
# Created BNet file: ./bnets/Invasion_net_8073.bnet
# Created BNet file: ./bnets/Invasion_net_8074.bnet
# Created BNet file: ./bnets/Invasion_net_8075.bnet
# Created BNet file: ./bnets/Invasion_net_8076.bnet
# Created BNet file: ./bnets/Invasion_net_8077.bnet
# Created BNet file: ./bnets/Invasion_net_8078.bnet
# Created BNet file: ./bnets/Invasion_net_8079.bnet
# Created BNet file: ./bnets/Invasion_net_8080.bnet
# Created BNet file: ./bnets/Invasion_net_8081.bnet
# Created BNet file: ./bnets/Invasion_net_8082.bnet
# Created BNet file: ./bnets/Invasion_net_8083.bnet
# Created BNet file: ./bnets/Invasion_net_8084.bnet
# Created BNet file: ./bnets/Invasion_net_8085.bnet
# Created BNet file: ./bnets/Invasion_net_8086.bnet
# Created BNet file: ./bnets/Invasion_net_8087.bnet
# Created BNet file: ./bnets/Invasion_net_8088.bnet
# Created BNet file: ./bnets/Invasion_net_8089.bnet
# Created BNet file: ./bnets/Invasion_net_8090.bnet
# Created BNet file: ./bnets/Invasion_net_8091.bnet
# Created BNet file: ./bnets/Invasion_net_8092.bnet
# Created BNet file: ./bnets/Invasion_net_8093.bnet
# Created BNet file: ./bnets/Invasion_net_8094.bnet
# Created BNet file: ./bnets/Invasion_net_8095.bnet
# Created BNet file: ./bnets/Invasion_net_8096.bnet
# Created BNet file: ./bnets/Invasion_net_8097.bnet
# Created BNet file: ./bnets/Invasion_net_8098.bnet
# Created BNet file: ./bnets/Invasion_net_8099.bnet
# Created BNet file: ./bnets/Invasion_net_8100.bnet
# Created BNet file: ./bnets/Invasion_net_8101.bnet
# Created BNet file: ./bnets/Invasion_net_8102.bnet
# Created BNet file: ./bnets/Invasion_net_8103.bnet
# Created BNet file: ./bnets/Invasion_net_8104.bnet
# Created BNet file: ./bnets/Invasion_net_8105.bnet
# Created BNet file: ./bnets/Invasion_net_8106.bnet
# Created BNet file: ./bnets/Invasion_net_8107.bnet
# Created BNet file: ./bnets/Invasion_net_8108.bnet
# Created BNet file: ./bnets/Invasion_net_8109.bnet
# Created BNet file: ./bnets/Invasion_net_8110.bnet
# Created BNet file: ./bnets/Invasion_net_8111.bnet
# Created BNet file: ./bnets/Invasion_net_8112.bnet
# Created BNet file: ./bnets/Invasion_net_8113.bnet
# Created BNet file: ./bnets/Invasion_net_8114.bnet
# Created BNet file: ./bnets/Invasion_net_8115.bnet
# Created BNet file: ./bnets/Invasion_net_8116.bnet
# Created BNet file: ./bnets/Invasion_net_8117.bnet
# Created BNet file: ./bnets/Invasion_net_8118.bnet
# Created BNet file: ./bnets/Invasion_net_8119.bnet
# Created BNet file: ./bnets/Invasion_net_8120.bnet
# Created BNet file: ./bnets/Invasion_net_8121.bnet
# Created BNet file: ./bnets/Invasion_net_8122.bnet
# Created BNet file: ./bnets/Invasion_net_8123.bnet
# Created BNet file: ./bnets/Invasion_net_8124.bnet
# Created BNet file: ./bnets/Invasion_net_8125.bnet
# Created BNet file: ./bnets/Invasion_net_8126.bnet
# Created BNet file: ./bnets/Invasion_net_8127.bnet
# Created BNet file: ./bnets/Invasion_net_8128.bnet
# Created BNet file: ./bnets/Invasion_net_8129.bnet
# Created BNet file: ./bnets/Invasion_net_8130.bnet
# Created BNet file: ./bnets/Invasion_net_8131.bnet
# Created BNet file: ./bnets/Invasion_net_8132.bnet
# Created BNet file: ./bnets/Invasion_net_8133.bnet
# Created BNet file: ./bnets/Invasion_net_8134.bnet
# Created BNet file: ./bnets/Invasion_net_8135.bnet
# Created BNet file: ./bnets/Invasion_net_8136.bnet
# Created BNet file: ./bnets/Invasion_net_8137.bnet
# Created BNet file: ./bnets/Invasion_net_8138.bnet
# Created BNet file: ./bnets/Invasion_net_8139.bnet
# Created BNet file: ./bnets/Invasion_net_8140.bnet
# Created BNet file: ./bnets/Invasion_net_8141.bnet
# Created BNet file: ./bnets/Invasion_net_8142.bnet
# Created BNet file: ./bnets/Invasion_net_8143.bnet
# Created BNet file: ./bnets/Invasion_net_8144.bnet
# Created BNet file: ./bnets/Invasion_net_8145.bnet
# Created BNet file: ./bnets/Invasion_net_8146.bnet
# Created BNet file: ./bnets/Invasion_net_8147.bnet
# Created BNet file: ./bnets/Invasion_net_8148.bnet
# Created BNet file: ./bnets/Invasion_net_8149.bnet
# Created BNet file: ./bnets/Invasion_net_8150.bnet
# Created BNet file: ./bnets/Invasion_net_8151.bnet
# Created BNet file: ./bnets/Invasion_net_8152.bnet
# Created BNet file: ./bnets/Invasion_net_8153.bnet
# Created BNet file: ./bnets/Invasion_net_8154.bnet
# Created BNet file: ./bnets/Invasion_net_8155.bnet
# Created BNet file: ./bnets/Invasion_net_8156.bnet
# Created BNet file: ./bnets/Invasion_net_8157.bnet
# Created BNet file: ./bnets/Invasion_net_8158.bnet
# Created BNet file: ./bnets/Invasion_net_8159.bnet
# Created BNet file: ./bnets/Invasion_net_8160.bnet
# Created BNet file: ./bnets/Invasion_net_8161.bnet
# Created BNet file: ./bnets/Invasion_net_8162.bnet
# Created BNet file: ./bnets/Invasion_net_8163.bnet
# Created BNet file: ./bnets/Invasion_net_8164.bnet
# Created BNet file: ./bnets/Invasion_net_8165.bnet
# Created BNet file: ./bnets/Invasion_net_8166.bnet
# Created BNet file: ./bnets/Invasion_net_8167.bnet
# Created BNet file: ./bnets/Invasion_net_8168.bnet
# Created BNet file: ./bnets/Invasion_net_8169.bnet
# Created BNet file: ./bnets/Invasion_net_8170.bnet
# Created BNet file: ./bnets/Invasion_net_8171.bnet
# Created BNet file: ./bnets/Invasion_net_8172.bnet
# Created BNet file: ./bnets/Invasion_net_8173.bnet
# Created BNet file: ./bnets/Invasion_net_8174.bnet
# Created BNet file: ./bnets/Invasion_net_8175.bnet
# Created BNet file: ./bnets/Invasion_net_8176.bnet
# Created BNet file: ./bnets/Invasion_net_8177.bnet
# Created BNet file: ./bnets/Invasion_net_8178.bnet
# Created BNet file: ./bnets/Invasion_net_8179.bnet
# Created BNet file: ./bnets/Invasion_net_8180.bnet
# Created BNet file: ./bnets/Invasion_net_8181.bnet
# Created BNet file: ./bnets/Invasion_net_8182.bnet
# Created BNet file: ./bnets/Invasion_net_8183.bnet
# Created BNet file: ./bnets/Invasion_net_8184.bnet
# Created BNet file: ./bnets/Invasion_net_8185.bnet
# Created BNet file: ./bnets/Invasion_net_8186.bnet
# Created BNet file: ./bnets/Invasion_net_8187.bnet
# Created BNet file: ./bnets/Invasion_net_8188.bnet
# Created BNet file: ./bnets/Invasion_net_8189.bnet
# Created BNet file: ./bnets/Invasion_net_8190.bnet
# Created BNet file: ./bnets/Invasion_net_8191.bnet
# Created BNet file: ./bnets/Invasion_net_8192.bnet
# Generated 8192 BNet files.

# %%
genesymbol = invasion_net.convert_edgelist_into_genesymbol()

# %% [markdown]
# # Final step: manually choose bimodal interactions

# %% [markdown]
# The final network contains 13 bimodal interactions which can be translated in 8192 different bnet files (and subsequentely 8192 models). One approach would be to use Ensamble MaBoSS to run all the models and analyze them. Another apporach is to manually choose the interactions based on our own prior knowledge and/or discussion with experts.

# %% [markdown]
# In order to chose the interactions, we decided to compare the network from NeKo with the invasion boolean mode from Ruscone et al. 2023.
#
# The following are the choice we made for each bimodal interaction:

# %% [markdown]
# MYC	inhibits cell-cell_adhesion
#
# AKT1	inhibits cell_migration	--> from Ruscone et al.	(AKT1 inhibits apoptosis)
#
# MAPK8	activates apoptotic_process --> from Ruscone et al. (MAPK8 activate AKT1 inhibits ERK inhibits apoptosis)
#
# MAPK8	activates cell-cell_adhesion
#
# PTEN	inhibits cell_migration
#
# CSNK2A1	activates TP53
#
# CSNK2A1	inhibits cell-cell_adhesion
#
# MDM2	inhibits apoptotic_process
#
# PAK2	activates apoptotic_process
#
# ROCK1	 activates cell_migration
#
# PRKD1	activates cell_migration
#
# MAPK14	inhibits AKT_family
#
# SIAH1	activates apoptotic_process

# %%
invasion_net.edges.loc[(invasion_net.edges['source'] == 'Q8IUQ4')& (invasion_net.edges['target'] == 'apoptotic_process'), 'Effect'] = 'stimulation'

# %%
export = Exports(invasion_net)

# %%
export.export_bnet("../sif_files/Invasion_net")
# Out:
# Created BNet file: ./Invasion_net_1.bnet
# Generated 1 BNet files.
